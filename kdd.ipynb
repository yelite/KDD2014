# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import f_classif
from scipy.stats import norm
import time
from sqlalchemy import create_engine

engine = create_engine('postgresql://localhost:5432/kdd')

# data = pd.HDFStore('data/data.h5', 'a')

# %%
# #donations = pd.read_csv('data/donations.csv', true_values=['t'], false_values=['f'])
# t = time.time()
# projects = pd.read_csv('data/projects.csv', true_values=['t'], false_values=['f'])
# print time.time() - t

outcomes = pd.read_csv('data/outcomes.csv', true_values=['t'], false_values=['f'])
#resources = pd.read_csv('data/resources.csv', true_values=['t'], false_values=['f'])
#essays = pd.read_csv('data/essays.csv', true_values=['t'], false_values=['f'])

# %%
outcomes.to_sql('outcomes', engine)

# %%
time.time()
# Out:
# 1404636228.420702

# %%
store = pd.HDFStore('store.h5')
# Out:
# /Users/Yelite/PyEnv/ML/lib/python2.7/site-packages/pandas/io/pytables.py:533: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   self._handle = tables.openFile(self._path, self._mode, **kwargs)

# %%
store.put('donations', donations, format='t')
# Out:
# /Users/Yelite/PyEnv/ML/lib/python2.7/site-packages/pandas/io/pytables.py:1041: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   return self._handle.getNode(self.root, key)
# /Users/Yelite/PyEnv/ML/lib/python2.7/site-packages/pandas/io/pytables.py:1041: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   return self._handle.getNode(self.root, key)
# /Users/Yelite/PyEnv/ML/lib/python2.7/site-packages/pandas/io/pytables.py:1041: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   return self._handle.getNode(self.root, key)
# ...

# %%
[essays[essays.is_exciting==True].descrtption_lenth.std(),
 essays[essays.is_exciting==False].descrtption_lenth.mean()]
# Out:
# Timestamp('2011-11-04 07:54:21.552000')

# %%
c_should = (outcomes.fully_funded==True) & (outcomes.at_least_1_green_donation==True) & (outcomes.great_chat==True) & (outcomes.three_or_more_non_teacher_referred_donors | outcomes.one_non_teacher_referred_donor_giving_100_plus | outcomes.donation_from_thoughtful_donor)
c_old = (outcomes.date_posted<='2010-03-14')
c_exciting = outcomes.is_exciting
c_new = outcomes.date_posted>'2010-03-14'

# %%
[len(outcomes[c_should & c_old]),
 len(outcomes[c_exciting & c_old]),
len(outcomes[c_should & c_new]),
len(outcomes[c_exciting & c_new]),
len(outcomes[outcomes.at_least_1_teacher_referred_donor & c_new]),
len(outcomes[c_new])]
# Out:
# [29999, 0, 93031, 36710, 124660, 425697]

# %%
outcomes
# Out:
#                                projectid is_exciting  \
# 0       ffffc4f85b60efc5b52347df489d0238       False
# 1       ffffac55ee02a49d1abc87ba6fc61135       False
# 2       ffff97ed93720407d70a2787475932b0       False
# 3       ffff418bb42fad24347527ad96100f81       False
# 4       ffff2d9c769c8fb5335e949c615425eb        True
# 5       fffeebf4827d745aa36b17c2d38d1966       False
# 6       fffee68353ade53e7692b23098096683       False
# 7       fffec078a2249c2365f3086a6eac7e4a       False
# 8       fffeb149cd9b85d802b2500368fd605e       False
# 9       fffeaae9482c9b72cab5bbd3f061d362       False
# 10      fffe700e315373fc1014290cf0c12f51       False
# 11      fffe598a41270538eab48432513513ab       False
# 12      fffe45b28ea6f2889de1e3f797fb31a3       False
# 13      fffe426c60834b0ba2eb05f759d854da       False
# 14      fffe0bb8af3b9cd93046b49653cc923a        True
# 15      fffe0476e16862c4892e97926489986c       False
# 16      fffdfdcf27588d2d32c15c12dec3a2cb       False
# ...
